# %% [markdown]
# # EV Charging transactions. Data cleaning, preprocressing, and feature engineering.

# %%
from pathlib import Path

# %%
import numpy as np
import polars as pl

# %%
# Imports
import json
import math
import os
from pathlib import Path

# %% [markdown]
# ## Load & Merge Source Files
#
# The raw charging transactions files are provided in the `data/raw` folder and were obtained from [National Grid UK](https://commercial.nationalgrid.co.uk/electric-nation-data).
# > They are provided as `parquet` files for efficient storage.

# %%
BASE_PATH = Path("../data/")

# %%
# Input file paths
INPUT_FILE1 = BASE_PATH / "raw" / "CrowdCharge_Transactions.parquet"
INPUT_FILE2 = BASE_PATH / "raw" / "GreenFlux_Transactions.parquet"

# %%
# Load parquet files and align schemas before merging
df1 = pl.read_parquet(INPUT_FILE1)[:, :21]
df2 = pl.read_parquet(INPUT_FILE2)[:, :21]

# Rename df2 columns to match df1 column order
df2 = df2.rename({old: new for old, new in zip(df2.columns, df1.columns)})

# Align dtypes between datasets
df1 = df1.with_columns(
    pl.col("ChargerID").cast(pl.Utf8),
    pl.col("Max_Current_Drawn_for_T").cast(pl.Float64),
)

# Concatenate and save merged file
df = pl.concat([df1, df2])
df.write_parquet(BASE_PATH / "processed" / "merged.parquet")

print(f"Merged dataset: {df.shape[0]:,} rows, {df.shape[1]} columns")
print(f"Unique chargers: {df.select(pl.col('ChargerID').n_unique()).item():,}")
df.head(8)
# Out:
# Merged dataset: 157,520 rows, 21 columns
# Unique chargers: 602
# shape: (8, 21)
# ┌────────────┬───────────┬────────────┬───────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ Transactio ┆ ChargerID ┆ Participan ┆ CarKW ┆ … ┆ EndCharge  ┆ ChargingD ┆ t_inactiv ┆ t_inactiv │
# │ nID        ┆ ---       ┆ tID        ┆ ---   ┆   ┆ ---        ┆ uration   ┆ e_start   ┆ e_end     │
# │ ---        ┆ str       ┆ ---        ┆ f64   ┆   ┆ datetime[n ┆ ---       ┆ ---       ┆ ---       │
# │ i64        ┆           ┆ str        ┆       ┆   ┆ s]         ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪═══════════╪════════════╪═══════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 100000     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100001     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100002     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100003     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100004     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100005     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100006     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100007     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# └────────────┴───────────┴────────────┴───────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Filter Outliers
#
# Remove outlier sessions (PluggedInTime outside 10–10,000 minutes)

# %%
df = df.filter(
    (pl.col("PluggedInTime") >= 10) &
    (pl.col("PluggedInTime") <= 10000)
)

print(f"After outlier filter: {df.shape[0]:,} rows")
df.head()
# Out:
# After outlier filter: 154,302 rows
# shape: (5, 21)
# ┌────────────┬───────────┬────────────┬───────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ Transactio ┆ ChargerID ┆ Participan ┆ CarKW ┆ … ┆ EndCharge  ┆ ChargingD ┆ t_inactiv ┆ t_inactiv │
# │ nID        ┆ ---       ┆ tID        ┆ ---   ┆   ┆ ---        ┆ uration   ┆ e_start   ┆ e_end     │
# │ ---        ┆ str       ┆ ---        ┆ f64   ┆   ┆ datetime[n ┆ ---       ┆ ---       ┆ ---       │
# │ i64        ┆           ┆ str        ┆       ┆   ┆ s]         ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪═══════════╪════════════╪═══════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 100000     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100001     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100002     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100003     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# │ 100004     ┆ 35000117  ┆ EN1306     ┆ 7.0   ┆ … ┆ null       ┆ null      ┆ null      ┆ null      │
# └────────────┴───────────┴────────────┴───────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Select relevant columns

# %%
df = df.select([
    "ChargerID",
    "AdjustedStartTime",
    "PluggedInTime",
    "ActiveCharging_Start",
    "ChargingDuration",
    "ConsumedkWh",
    "AdjustedStopTime",
    "Part_of_Managed_Group",
])

# Drop sessions with no recorded charging start
df = df.filter(pl.col("ActiveCharging_Start").is_not_null())

print(f"After column selection and null filter: {df.shape[0]:,} rows")
df.head(8)
# Out:
# After column selection and null filter: 111,179 rows
# shape: (8, 8)
# ┌───────────┬────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ ChargerID ┆ AdjustedSt ┆ PluggedInT ┆ ActiveChar ┆ ChargingD ┆ Consumedk ┆ AdjustedS ┆ Part_of_M │
# │ ---       ┆ artTime    ┆ ime        ┆ ging_Start ┆ uration   ┆ Wh        ┆ topTime   ┆ anaged_Gr │
# │ str       ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ oup       │
# │           ┆ datetime[n ┆ i64        ┆ datetime[n ┆ f64       ┆ f64       ┆ datetime[ ┆ ---       │
# │           ┆ s]         ┆            ┆ s]         ┆           ┆           ┆ ns]       ┆ str       │
# ╞═══════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 35000117  ┆ 2017-06-28 ┆ 601        ┆ 2017-06-28 ┆ 281.0     ┆ 31.23     ┆ 2017-06-2 ┆ No        │
# │           ┆ 21:04:00   ┆            ┆ 21:05:00   ┆           ┆           ┆ 9         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 07:05:00  ┆           │
# │ 35000117  ┆ 2017-07-03 ┆ 864        ┆ 2017-07-03 ┆ 233.0     ┆ 26.24     ┆ 2017-07-0 ┆ No        │
# │           ┆ 18:17:00   ┆            ┆ 18:19:00   ┆           ┆           ┆ 4         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 08:41:00  ┆           │
# │ 35000117  ┆ 2017-07-07 ┆ 1420       ┆ 2017-07-07 ┆ 187.0     ┆ 20.92     ┆ 2017-07-0 ┆ No        │
# │           ┆ 15:28:00   ┆            ┆ 15:29:00   ┆           ┆           ┆ 8         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 15:08:00  ┆           │
# │ 35000117  ┆ 2017-07-13 ┆ 5026       ┆ 2017-07-13 ┆ 264.0     ┆ 30.59     ┆ 2017-07-1 ┆ No        │
# │           ┆ 22:35:00   ┆            ┆ 22:36:00   ┆           ┆           ┆ 7         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 10:21:00  ┆           │
# │ 35000117  ┆ 2017-08-03 ┆ 732        ┆ 2017-08-03 ┆ 220.0     ┆ 24.88     ┆ 2017-08-0 ┆ No        │
# │           ┆ 21:34:00   ┆            ┆ 21:35:00   ┆           ┆           ┆ 4         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 09:46:00  ┆           │
# │ 35000117  ┆ 2017-08-11 ┆ 2670       ┆ 2017-08-11 ┆ 268.0     ┆ 30.71     ┆ 2017-08-1 ┆ No        │
# │           ┆ 15:56:00   ┆            ┆ 15:57:00   ┆           ┆           ┆ 3         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 12:26:00  ┆           │
# │ 35000117  ┆ 2017-08-18 ┆ 921        ┆ 2017-08-18 ┆ 265.0     ┆ 30.0      ┆ 2017-08-1 ┆ No        │
# │           ┆ 17:24:00   ┆            ┆ 17:25:00   ┆           ┆           ┆ 9         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 08:45:00  ┆           │
# │ 35000117  ┆ 2018-01-15 ┆ 858        ┆ 2018-01-15 ┆ 249.0     ┆ 32.1      ┆ 2018-01-1 ┆ No        │
# │           ┆ 17:25:00   ┆            ┆ 17:26:00   ┆           ┆           ┆ 6         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 07:43:00  ┆           │
# └───────────┴────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Feature Engineering

# %%
# Ensure datetime columns are correctly typed
NS_PER_HOUR = 3_600_000_000_000

for col in ["ActiveCharging_Start", "AdjustedStopTime"]:
    if df.schema[col] != pl.Datetime:
        df = df.with_columns(
            pl.col(col)
              .cast(pl.Utf8)
              .str.strip_chars()
              .str.replace_all("  +", " ")
              .str.to_datetime(strict=False)
        )

# %% [markdown]
# ### Compute ChargingDuration (hours) where missing

# %%
if "ChargingDuration" not in df.columns:
    df = df.with_columns(pl.lit(None, dtype=pl.Duration).alias("ChargingDuration"))

df = df.with_columns(
    pl.when(
        pl.col("ChargingDuration").is_null()
        & pl.col("ActiveCharging_Start").is_not_null()
        & pl.col("AdjustedStopTime").is_not_null()
    )
    .then(
        (pl.col("AdjustedStopTime").dt.epoch("ns") - pl.col("ActiveCharging_Start").dt.epoch("ns"))
        / NS_PER_HOUR
    )
    .otherwise(pl.col("ChargingDuration"))
    .cast(pl.Float64)
    .alias("ChargingDuration")
)

df.head()
# Out:
# shape: (5, 8)
# ┌───────────┬────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ ChargerID ┆ AdjustedSt ┆ PluggedInT ┆ ActiveChar ┆ ChargingD ┆ Consumedk ┆ AdjustedS ┆ Part_of_M │
# │ ---       ┆ artTime    ┆ ime        ┆ ging_Start ┆ uration   ┆ Wh        ┆ topTime   ┆ anaged_Gr │
# │ str       ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ oup       │
# │           ┆ datetime[n ┆ i64        ┆ datetime[n ┆ f64       ┆ f64       ┆ datetime[ ┆ ---       │
# │           ┆ s]         ┆            ┆ s]         ┆           ┆           ┆ ns]       ┆ str       │
# ╞═══════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 35000117  ┆ 2017-06-28 ┆ 601        ┆ 2017-06-28 ┆ 281.0     ┆ 31.23     ┆ 2017-06-2 ┆ No        │
# │           ┆ 21:04:00   ┆            ┆ 21:05:00   ┆           ┆           ┆ 9         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 07:05:00  ┆           │
# │ 35000117  ┆ 2017-07-03 ┆ 864        ┆ 2017-07-03 ┆ 233.0     ┆ 26.24     ┆ 2017-07-0 ┆ No        │
# │           ┆ 18:17:00   ┆            ┆ 18:19:00   ┆           ┆           ┆ 4         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 08:41:00  ┆           │
# │ 35000117  ┆ 2017-07-07 ┆ 1420       ┆ 2017-07-07 ┆ 187.0     ┆ 20.92     ┆ 2017-07-0 ┆ No        │
# │           ┆ 15:28:00   ┆            ┆ 15:29:00   ┆           ┆           ┆ 8         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 15:08:00  ┆           │
# │ 35000117  ┆ 2017-07-13 ┆ 5026       ┆ 2017-07-13 ┆ 264.0     ┆ 30.59     ┆ 2017-07-1 ┆ No        │
# │           ┆ 22:35:00   ┆            ┆ 22:36:00   ┆           ┆           ┆ 7         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 10:21:00  ┆           │
# │ 35000117  ┆ 2017-08-03 ┆ 732        ┆ 2017-08-03 ┆ 220.0     ┆ 24.88     ┆ 2017-08-0 ┆ No        │
# │           ┆ 21:34:00   ┆            ┆ 21:35:00   ┆           ┆           ┆ 4         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 09:46:00  ┆           │
# └───────────┴────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Encode Part_of_Managed_Group as binary integer

# %%
df = df.with_columns(
    pl.col("Part_of_Managed_Group")
      .replace({"Yes": 1, "No": 0})
      .cast(pl.Int8)
      .alias("Part_of_Managed_Group")
)
df.head()
# Out:
# shape: (5, 8)
# ┌───────────┬────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ ChargerID ┆ AdjustedSt ┆ PluggedInT ┆ ActiveChar ┆ ChargingD ┆ Consumedk ┆ AdjustedS ┆ Part_of_M │
# │ ---       ┆ artTime    ┆ ime        ┆ ging_Start ┆ uration   ┆ Wh        ┆ topTime   ┆ anaged_Gr │
# │ str       ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ oup       │
# │           ┆ datetime[n ┆ i64        ┆ datetime[n ┆ f64       ┆ f64       ┆ datetime[ ┆ ---       │
# │           ┆ s]         ┆            ┆ s]         ┆           ┆           ┆ ns]       ┆ i8        │
# ╞═══════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 35000117  ┆ 2017-06-28 ┆ 601        ┆ 2017-06-28 ┆ 281.0     ┆ 31.23     ┆ 2017-06-2 ┆ 0         │
# │           ┆ 21:04:00   ┆            ┆ 21:05:00   ┆           ┆           ┆ 9         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 07:05:00  ┆           │
# │ 35000117  ┆ 2017-07-03 ┆ 864        ┆ 2017-07-03 ┆ 233.0     ┆ 26.24     ┆ 2017-07-0 ┆ 0         │
# │           ┆ 18:17:00   ┆            ┆ 18:19:00   ┆           ┆           ┆ 4         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 08:41:00  ┆           │
# │ 35000117  ┆ 2017-07-07 ┆ 1420       ┆ 2017-07-07 ┆ 187.0     ┆ 20.92     ┆ 2017-07-0 ┆ 0         │
# │           ┆ 15:28:00   ┆            ┆ 15:29:00   ┆           ┆           ┆ 8         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 15:08:00  ┆           │
# │ 35000117  ┆ 2017-07-13 ┆ 5026       ┆ 2017-07-13 ┆ 264.0     ┆ 30.59     ┆ 2017-07-1 ┆ 0         │
# │           ┆ 22:35:00   ┆            ┆ 22:36:00   ┆           ┆           ┆ 7         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 10:21:00  ┆           │
# │ 35000117  ┆ 2017-08-03 ┆ 732        ┆ 2017-08-03 ┆ 220.0     ┆ 24.88     ┆ 2017-08-0 ┆ 0         │
# │           ┆ 21:34:00   ┆            ┆ 21:35:00   ┆           ┆           ┆ 4         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 09:46:00  ┆           │
# └───────────┴────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Convert PluggedInTime and ChargingDuration from minutes to hours

# %%
df = df.with_columns(
    pl.col("PluggedInTime").cast(pl.Float64) / 60,
    pl.col("ChargingDuration").cast(pl.Float64) / 60,
)
df.head()
# Out:
# shape: (5, 8)
# ┌───────────┬────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┐
# │ ChargerID ┆ AdjustedSt ┆ PluggedInT ┆ ActiveChar ┆ ChargingD ┆ Consumedk ┆ AdjustedS ┆ Part_of_M │
# │ ---       ┆ artTime    ┆ ime        ┆ ging_Start ┆ uration   ┆ Wh        ┆ topTime   ┆ anaged_Gr │
# │ str       ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ oup       │
# │           ┆ datetime[n ┆ f64        ┆ datetime[n ┆ f64       ┆ f64       ┆ datetime[ ┆ ---       │
# │           ┆ s]         ┆            ┆ s]         ┆           ┆           ┆ ns]       ┆ i8        │
# ╞═══════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 35000117  ┆ 2017-06-28 ┆ 10.016667  ┆ 2017-06-28 ┆ 4.683333  ┆ 31.23     ┆ 2017-06-2 ┆ 0         │
# │           ┆ 21:04:00   ┆            ┆ 21:05:00   ┆           ┆           ┆ 9         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 07:05:00  ┆           │
# │ 35000117  ┆ 2017-07-03 ┆ 14.4       ┆ 2017-07-03 ┆ 3.883333  ┆ 26.24     ┆ 2017-07-0 ┆ 0         │
# │           ┆ 18:17:00   ┆            ┆ 18:19:00   ┆           ┆           ┆ 4         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 08:41:00  ┆           │
# │ 35000117  ┆ 2017-07-07 ┆ 23.666667  ┆ 2017-07-07 ┆ 3.116667  ┆ 20.92     ┆ 2017-07-0 ┆ 0         │
# │           ┆ 15:28:00   ┆            ┆ 15:29:00   ┆           ┆           ┆ 8         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 15:08:00  ┆           │
# │ 35000117  ┆ 2017-07-13 ┆ 83.766667  ┆ 2017-07-13 ┆ 4.4       ┆ 30.59     ┆ 2017-07-1 ┆ 0         │
# │           ┆ 22:35:00   ┆            ┆ 22:36:00   ┆           ┆           ┆ 7         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 10:21:00  ┆           │
# │ 35000117  ┆ 2017-08-03 ┆ 12.2       ┆ 2017-08-03 ┆ 3.666667  ┆ 24.88     ┆ 2017-08-0 ┆ 0         │
# │           ┆ 21:34:00   ┆            ┆ 21:35:00   ┆           ┆           ┆ 4         ┆           │
# │           ┆            ┆            ┆            ┆           ┆           ┆ 09:46:00  ┆           │
# └───────────┴────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### Compute time gap between plug-in and charging start (hours)

# %%
df = df.with_columns(
    (
        (pl.col("ActiveCharging_Start").dt.epoch("ns") - pl.col("AdjustedStartTime").dt.epoch("ns"))
        / 3_600_000_000_000
    ).cast(pl.Float64).clip(lower_bound=0).alias("TimeGapHours"),

    # Temporal features
    pl.col("AdjustedStartTime").dt.hour().cast(pl.Float64).alias("HourOfDay"),
    pl.col("AdjustedStartTime").dt.weekday().cast(pl.Float64).alias("DayOfWeek"),
)
df.head()
# Out:
# shape: (5, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ChargerID ┆ AdjustedS ┆ PluggedIn ┆ ActiveCha ┆ … ┆ Part_of_M ┆ TimeGapHo ┆ HourOfDay ┆ DayOfWee │
# │ ---       ┆ tartTime  ┆ Time      ┆ rging_Sta ┆   ┆ anaged_Gr ┆ urs       ┆ ---       ┆ k        │
# │ str       ┆ ---       ┆ ---       ┆ rt        ┆   ┆ oup       ┆ ---       ┆ f64       ┆ ---      │
# │           ┆ datetime[ ┆ f64       ┆ ---       ┆   ┆ ---       ┆ f64       ┆           ┆ f64      │
# │           ┆ ns]       ┆           ┆ datetime[ ┆   ┆ i8        ┆           ┆           ┆          │
# │           ┆           ┆           ┆ ns]       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 35000117  ┆ 2017-06-2 ┆ 10.016667 ┆ 2017-06-2 ┆ … ┆ 0         ┆ 0.016667  ┆ 21.0      ┆ 3.0      │
# │           ┆ 8         ┆           ┆ 8         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 21:04:00  ┆           ┆ 21:05:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-07-0 ┆ 14.4      ┆ 2017-07-0 ┆ … ┆ 0         ┆ 0.033333  ┆ 18.0      ┆ 1.0      │
# │           ┆ 3         ┆           ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 18:17:00  ┆           ┆ 18:19:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-07-0 ┆ 23.666667 ┆ 2017-07-0 ┆ … ┆ 0         ┆ 0.016667  ┆ 15.0      ┆ 5.0      │
# │           ┆ 7         ┆           ┆ 7         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 15:28:00  ┆           ┆ 15:29:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-07-1 ┆ 83.766667 ┆ 2017-07-1 ┆ … ┆ 0         ┆ 0.016667  ┆ 22.0      ┆ 4.0      │
# │           ┆ 3         ┆           ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 22:35:00  ┆           ┆ 22:36:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-08-0 ┆ 12.2      ┆ 2017-08-0 ┆ … ┆ 0         ┆ 0.016667  ┆ 21.0      ┆ 4.0      │
# │           ┆ 3         ┆           ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 21:34:00  ┆           ┆ 21:35:00  ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ### Shift DayOfWeek so Monday = 0

# %%
df = df.with_columns(
    (pl.col("DayOfWeek") - 1).alias("DayOfWeek")
)

df.head()
# Out:
# shape: (5, 11)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ChargerID ┆ AdjustedS ┆ PluggedIn ┆ ActiveCha ┆ … ┆ Part_of_M ┆ TimeGapHo ┆ HourOfDay ┆ DayOfWee │
# │ ---       ┆ tartTime  ┆ Time      ┆ rging_Sta ┆   ┆ anaged_Gr ┆ urs       ┆ ---       ┆ k        │
# │ str       ┆ ---       ┆ ---       ┆ rt        ┆   ┆ oup       ┆ ---       ┆ f64       ┆ ---      │
# │           ┆ datetime[ ┆ f64       ┆ ---       ┆   ┆ ---       ┆ f64       ┆           ┆ f64      │
# │           ┆ ns]       ┆           ┆ datetime[ ┆   ┆ i8        ┆           ┆           ┆          │
# │           ┆           ┆           ┆ ns]       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 35000117  ┆ 2017-06-2 ┆ 10.016667 ┆ 2017-06-2 ┆ … ┆ 0         ┆ 0.016667  ┆ 21.0      ┆ 2.0      │
# │           ┆ 8         ┆           ┆ 8         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 21:04:00  ┆           ┆ 21:05:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-07-0 ┆ 14.4      ┆ 2017-07-0 ┆ … ┆ 0         ┆ 0.033333  ┆ 18.0      ┆ 0.0      │
# │           ┆ 3         ┆           ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 18:17:00  ┆           ┆ 18:19:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-07-0 ┆ 23.666667 ┆ 2017-07-0 ┆ … ┆ 0         ┆ 0.016667  ┆ 15.0      ┆ 4.0      │
# │           ┆ 7         ┆           ┆ 7         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 15:28:00  ┆           ┆ 15:29:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-07-1 ┆ 83.766667 ┆ 2017-07-1 ┆ … ┆ 0         ┆ 0.016667  ┆ 22.0      ┆ 3.0      │
# │           ┆ 3         ┆           ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 22:35:00  ┆           ┆ 22:36:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-08-0 ┆ 12.2      ┆ 2017-08-0 ┆ … ┆ 0         ┆ 0.016667  ┆ 21.0      ┆ 3.0      │
# │           ┆ 3         ┆           ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 21:34:00  ┆           ┆ 21:35:00  ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ### Cyclic encoding of session start time within the week

# %%
SECONDS_PER_DAY  = 86_400
SECONDS_PER_WEEK = 604_800

week_position = (
    (pl.col("AdjustedStartTime").dt.weekday() - 1).cast(pl.Int64) * SECONDS_PER_DAY
    + (pl.col("AdjustedStartTime").dt.epoch("s") % SECONDS_PER_DAY)
)

df = df.with_columns([
    ((2 * math.pi) * week_position / SECONDS_PER_WEEK).sin().alias("WeekTime_sin"),
    ((2 * math.pi) * week_position / SECONDS_PER_WEEK).cos().alias("WeekTime_cos"),
])

print(f"Final dataset: {df.shape[0]:,} rows")
df.head()
# Out:
# Final dataset: 111,179 rows
# shape: (5, 13)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ ChargerID ┆ AdjustedS ┆ PluggedIn ┆ ActiveCha ┆ … ┆ HourOfDay ┆ DayOfWeek ┆ WeekTime_ ┆ WeekTime │
# │ ---       ┆ tartTime  ┆ Time      ┆ rging_Sta ┆   ┆ ---       ┆ ---       ┆ sin       ┆ _cos     │
# │ str       ┆ ---       ┆ ---       ┆ rt        ┆   ┆ f64       ┆ f64       ┆ ---       ┆ ---      │
# │           ┆ datetime[ ┆ f64       ┆ ---       ┆   ┆           ┆           ┆ f64       ┆ f64      │
# │           ┆ ns]       ┆           ┆ datetime[ ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ ns]       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 35000117  ┆ 2017-06-2 ┆ 10.016667 ┆ 2017-06-2 ┆ … ┆ 21.0      ┆ 2.0       ┆ 0.529919  ┆ -0.84804 │
# │           ┆ 8         ┆           ┆ 8         ┆   ┆           ┆           ┆           ┆ 8        │
# │           ┆ 21:04:00  ┆           ┆ 21:05:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-07-0 ┆ 14.4      ┆ 2017-07-0 ┆ … ┆ 18.0      ┆ 0.0       ┆ 0.631739  ┆ 0.775181 │
# │           ┆ 3         ┆           ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │           ┆ 18:17:00  ┆           ┆ 18:19:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-07-0 ┆ 23.666667 ┆ 2017-07-0 ┆ … ┆ 15.0      ┆ 4.0       ┆ -0.85588  ┆ -0.51717 │
# │           ┆ 7         ┆           ┆ 7         ┆   ┆           ┆           ┆           ┆ 4        │
# │           ┆ 15:28:00  ┆           ┆ 15:29:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-07-1 ┆ 83.766667 ┆ 2017-07-1 ┆ … ┆ 22.0      ┆ 3.0       ┆ -0.385561 ┆ -0.92268 │
# │           ┆ 3         ┆           ┆ 3         ┆   ┆           ┆           ┆           ┆ 2        │
# │           ┆ 22:35:00  ┆           ┆ 22:36:00  ┆   ┆           ┆           ┆           ┆          │
# │ 35000117  ┆ 2017-08-0 ┆ 12.2      ┆ 2017-08-0 ┆ … ┆ 21.0      ┆ 3.0       ┆ -0.350207 ┆ -0.93667 │
# │           ┆ 3         ┆           ┆ 3         ┆   ┆           ┆           ┆           ┆ 2        │
# │           ┆ 21:34:00  ┆           ┆ 21:35:00  ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Validation

# %%
# Summary statistics for a mid-week slice (Wednesday, DayOfWeek == 2)
wednesday = df.filter(pl.col("DayOfWeek") == 2).select([
    "PluggedInTime", "ChargingDuration", "ConsumedkWh",
    "TimeGapHours", "WeekTime_sin", "WeekTime_cos"
])

print(f"Wednesday session count: {wednesday.shape[0]:,}")
print("\nMean:\n",  wednesday.select(pl.all().mean()))
print("\nStd:\n",   wednesday.select(pl.all().std()))
# Out:
# Wednesday session count: 16,389
#
# Mean:
#  shape: (1, 6)
# ┌───────────────┬──────────────────┬─────────────┬──────────────┬──────────────┬──────────────┐
# │ PluggedInTime ┆ ChargingDuration ┆ ConsumedkWh ┆ TimeGapHours ┆ WeekTime_sin ┆ WeekTime_cos │
# │ ---           ┆ ---              ┆ ---         ┆ ---          ┆ ---          ┆ ---          │
# │ f64           ┆ f64              ┆ f64         ┆ f64          ┆ f64          ┆ f64          │
# ╞═══════════════╪══════════════════╪═════════════╪══════════════╪══════════════╪══════════════╡
# │ 11.522936     ┆ 2.35149          ┆ 10.651873   ┆ 1.223974     ┆ 0.63241      ┆ -0.760117    │
# └───────────────┴──────────────────┴─────────────┴──────────────┴──────────────┴──────────────┘
#
# Std:
#  shape: (1, 6)
# ┌───────────────┬──────────────────┬─────────────┬──────────────┬──────────────┬──────────────┐
# │ PluggedInTime ┆ ChargingDuration ┆ ConsumedkWh ┆ TimeGapHours ┆ WeekTime_sin ┆ WeekTime_cos │
# │ ---           ┆ ---              ┆ ---         ┆ ---          ┆ ---          ┆ ---          │
# │ f64           ┆ f64              ┆ f64         ┆ f64          ┆ f64          ┆ f64          │
# ╞═══════════════╪══════════════════╪═════════════╪══════════════╪══════════════╪══════════════╡
# │ 11.250608     ┆ 2.273617         ┆ 11.926986   ┆ 2.990244     ┆ 0.105717     ┆ 0.105376     │
# └───────────────┴──────────────────┴─────────────┴──────────────┴──────────────┴──────────────┘

# %% [markdown]
# ## Save Outputs

# %%
# Save full cleaned dataset (with timestamps retained for reference)
FULL_CLEANED_PATH = BASE_PATH / "processed" / "Real_transactions_cleaned.parquet"
df.write_parquet(FULL_CLEANED_PATH)
print(f"Saved full cleaned data: {df.shape[0]:,} rows -> {FULL_CLEANED_PATH}")
# Out:
# Saved full cleaned data: 111,179 rows -> ../data/processed/Real_transactions_cleaned.parquet

# %%
# Drop columns not needed for model training and save pre-scale dataset
df_model = df.drop(
    "ChargerID", "AdjustedStartTime", "ActiveCharging_Start",
    "AdjustedStopTime", "HourOfDay"
)

PRE_SCALE = BASE_PATH / "processed" / "Transactions_preprocessedV3.4.7_combined.parquet"
df_model.write_parquet(PRE_SCALE)
print(f"Saved pre-scale model input: {df_model.shape[0]:,} rows -> {PRE_SCALE}")
df_model.head()
# Out:
# Saved pre-scale model input: 111,179 rows -> ../data/processed/Transactions_preprocessedV3.4.7_combined.parquet
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ PluggedInT ┆ ChargingDu ┆ ConsumedkW ┆ Part_of_M ┆ TimeGapHo ┆ DayOfWeek ┆ WeekTime_ ┆ WeekTime_ │
# │ ime        ┆ ration     ┆ h          ┆ anaged_Gr ┆ urs       ┆ ---       ┆ sin       ┆ cos       │
# │ ---        ┆ ---        ┆ ---        ┆ oup       ┆ ---       ┆ f64       ┆ ---       ┆ ---       │
# │ f64        ┆ f64        ┆ f64        ┆ ---       ┆ f64       ┆           ┆ f64       ┆ f64       │
# │            ┆            ┆            ┆ i8        ┆           ┆           ┆           ┆           │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 10.016667  ┆ 4.683333   ┆ 31.23      ┆ 0         ┆ 0.016667  ┆ 2.0       ┆ 0.529919  ┆ -0.848048 │
# │ 14.4       ┆ 3.883333   ┆ 26.24      ┆ 0         ┆ 0.033333  ┆ 0.0       ┆ 0.631739  ┆ 0.775181  │
# │ 23.666667  ┆ 3.116667   ┆ 20.92      ┆ 0         ┆ 0.016667  ┆ 4.0       ┆ -0.85588  ┆ -0.517174 │
# │ 83.766667  ┆ 4.4        ┆ 30.59      ┆ 0         ┆ 0.016667  ┆ 3.0       ┆ -0.385561 ┆ -0.922682 │
# │ 12.2       ┆ 3.666667   ┆ 24.88      ┆ 0         ┆ 0.016667  ┆ 3.0       ┆ -0.350207 ┆ -0.936672 │
# └────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴───────────┴───────────┘
